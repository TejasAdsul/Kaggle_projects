# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
train_data = pd.read_csv('train_concrete.csv')
test_data = pd.read_csv('test_concrete.csv')
train_data.head()
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   425.0  106.3     0.0  153.5              16.5            852.1
# 1   212.1    0.0   121.6  180.3               5.7           1057.6
# 2   165.0    0.0   143.6  163.8               0.0           1005.6
# 3   260.9  100.5    78.3  200.6               8.6            864.5
# 4   540.0    0.0     0.0  173.0               0.0           1125.0
#
#    fineaggregate  age  csMPa
# 0          887.1   28  60.29
# 1          779.3  100  39.61
# 2          900.9   28  26.20
# 3          761.5   28  32.40
# 4          613.0    7  52.61

# %%
test_data.head()
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   349.0    0.0     0.0  192.0               0.0           1047.0
# 1   276.0  116.0    90.0  180.0               9.0            870.0
# 2   139.7  163.9   127.7  236.7               5.8            868.6
# 3   296.0    0.0   107.0  221.0              11.0            819.0
# 4   385.0    0.0     0.0  186.0               0.0            966.0
#
#    fineaggregate  age  csMPa
# 0          806.0  360  42.13
# 1          768.0   28  44.28
# 2          655.6   28  35.23
# 3          778.0   28  31.42
# 4          763.0   14  27.92

# %%
corr = train_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_2574c_row0_col0,#T_2574c_row1_col1,#T_2574c_row2_col2,#T_2574c_row3_col3,#T_2574c_row4_col4,#T_2574c_row5_col5,#T_2574c_row6_col6,#T_2574c_row7_col7,#T_2574c_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_2574c_row0_col1{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_2574c_row0_col2,#T_2574c_row1_col5,#T_2574c_row2_col0,#T_2574c_row2_col1,#T_2574c_row3_col4,#T_2574c_row3_col6,#T_2574c_row3_col8,#T_2574c_row4_col3,#T_2574c_row4_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_2574c_row0_col3,#T_2574c_row2_col6{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_2574c_row0_col4,#T_2574c_row1_col3{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_2574c_row0_col5,#T_2574c_row0_col6,#T_2574c_row6_col3{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_2574c_row0_col7{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_2574c_row0_col8,#T_2574c_row8_col4{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_2574c_row1_col0,#T_2574c_row6_col8{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_2574c_row1_col2{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_2574c_row1_col4{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_2574c_row1_col6,#T_2574c_row3_col2,#T_2574c_row5_col8{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_2574c_row1_col7{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_2574c_row1_col8,#T_2574c_row4_col0{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_2574c_row2_col3{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_2574c_row2_col4{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_2574c_row2_col5,#T_2574c_row5_col0,#T_2574c_row8_col2{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_2574c_row2_col7{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_2574c_row2_col8{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_2574c_row3_col0{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_2574c_row3_col1{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_2574c_row3_col5{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_2574c_row3_col7{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_2574c_row4_col1{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_2574c_row4_col2{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_2574c_row4_col5{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_2574c_row4_col6{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_2574c_row4_col8{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_2574c_row5_col1{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_2574c_row5_col2{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_2574c_row5_col3{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_2574c_row5_col4{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_2574c_row5_col6{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_2574c_row5_col7{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_2574c_row6_col0{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_2574c_row6_col1{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_2574c_row6_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_2574c_row6_col4{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_2574c_row6_col5{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_2574c_row6_col7{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_2574c_row7_col0{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_2574c_row7_col1{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_2574c_row7_col2{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_2574c_row7_col3{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_2574c_row7_col4{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_2574c_row7_col5{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_2574c_row7_col6{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_2574c_row7_col8{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_2574c_row8_col0{
#             background-color:  #f6bea4;
#             color:  #000000;
#         }#T_2574c_row8_col1{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_2574c_row8_col3{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_2574c_row8_col5{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_2574c_row8_col6{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_2574c_row8_col7{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }</style><table id="T_2574c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cement</th>        <th class="col_heading level0 col1" >slag</th>        <th class="col_heading level0 col2" >flyash</th>        <th class="col_heading level0 col3" >water</th>        <th class="col_heading level0 col4" >superplasticizer</th>        <th class="col_heading level0 col5" >coarseaggregate</th>        <th class="col_heading level0 col6" >fineaggregate</th>        <th class="col_heading level0 col7" >age</th>        <th class="col_heading level0 col8" >csMPa</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2574c_level0_row0" class="row_heading level0 row0" >cement</th>
#                         <td id="T_2574c_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_2574c_row0_col1" class="data row0 col1" >-0.272043</td>
#                         <td id="T_2574c_row0_col2" class="data row0 col2" >-0.394003</td>
#                         <td id="T_2574c_row0_col3" class="data row0 col3" >-0.087360</td>
#                         <td id="T_2574c_row0_col4" class="data row0 col4" >0.089716</td>
#                         <td id="T_2574c_row0_col5" class="data row0 col5" >-0.105651</td>
#                         <td id="T_2574c_row0_col6" class="data row0 col6" >-0.226412</td>
#                         <td id="T_2574c_row0_col7" class="data row0 col7" >0.090677</td>
#                         <td id="T_2574c_row0_col8" class="data row0 col8" >0.507032</td>
#             </tr>
#             <tr>
#                         <th id="T_2574c_level0_row1" class="row_heading level0 row1" >slag</th>
#                         <td id="T_2574c_row1_col0" class="data row1 col0" >-0.272043</td>
#                         <td id="T_2574c_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_2574c_row1_col2" class="data row1 col2" >-0.320389</td>
#                         <td id="T_2574c_row1_col3" class="data row1 col3" >0.088269</td>
#                         <td id="T_2574c_row1_col4" class="data row1 col4" >0.080963</td>
#                         <td id="T_

# %%
X = train_data.drop(labels=['csMPa'], axis=1)
y = train_data['csMPa']
X_test = test_data.drop(labels=['csMPa'], axis=1)
y_test = test_data['csMPa']

# %%
len(X_test)
# Out:
# 206

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=69)

# %%
n_estimators = [10,50,100,200,300,500]
max_depths = [1,2,3,4,5,6,7]
mses = {}

for n_estimator in n_estimators:
    for max_depth in max_depths:
        regressor = RandomForestRegressor(n_estimators=n_estimator, max_depth=max_depth)
        regressor.fit(X_train, y_train)
        y_out = regressor.predict(X_val)
        mse = mean_squared_error(y_val,y_out)
        mses[f'estimators {n_estimator}, max_depths {max_depth}'] = mse

# %%
min_value = np.min(list(mses.values()))
best_hp = list(mses.keys())[list(mses.values()).index(min_value)]
print("Best HPs", best_hp)
n_estimators = best_hp.split(' ')[1].replace(',','')
max_depth = best_hp.split(' ')[3]

regressor = RandomForestRegressor(n_estimators=int(n_estimators), max_depth=int(max_depth))
regressor.fit(X_train, y_train)
y_out = regressor.predict(X_val)
print(f'Validation error: {np.sqrt(mean_squared_error(y_val,y_out))}')
y_out = regressor.predict(X_test)
print(f'Test error: {np.sqrt(mean_squared_error(y_test,y_out))}')
# Out:
# Best HPs estimators 300, max_depths 7
# Validation error: 6.118540214651163
# Test error: 5.68091521448381

# %%
grid = GridSearchCV(estimator=RandomForestRegressor(), param_grid={'n_estimators': [10,50,99,200,300,500], 'max_depth':[1,2,3,4,5,6,7]}, cv=5)
grid.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [1, 2, 3, 4, 5, 6, 7],
#                          'n_estimators': [10, 50, 99, 200, 300, 500]})

# %%
grid.best_estimator_
# Out:
# RandomForestRegressor(max_depth=7, n_estimators=99)

# %%
def evaluate(model, test_features, test_labels):
    y_out = model.predict(test_features)
    mse = mean_squared_error(test_labels,y_out)
    rmse = np.sqrt(mse)
    
    print('Model Performance')
    print(f'Root Mean Squared Error: {rmse}')

# %%
evaluate(grid.best_estimator_, X_val, y_val)
evaluate(grid.best_estimator_, X_test, y_test)
# Out:
# Model Performance
# Root Mean Squared Error: 6.151391345419112
# Model Performance
# Root Mean Squared Error: 5.662935554411537
