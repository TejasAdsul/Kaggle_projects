# %%
# %matplotlib inline
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Import cleaned data
df_train = pd.read_csv('cleaned_train_concrete.csv')
df_test = pd.read_csv('cleaned_test_concrete.csv')

# %%
# Numerical exploration
print('Summary: \n',df_train.head(),'\n')
print('Shape: \n',df_train.shape,'\n')
print('Description: \n',df_train.describe(),'\n')
print('Number of unique values in each column: \n',df_train.nunique(axis=0),'\n')
# Out:
# Summary:
#     cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   425.0  106.3     0.0  153.5              16.5            852.1
# 1   212.1    0.0   121.6  180.3               5.7           1057.6
# 2   165.0    0.0   143.6  163.8               0.0           1005.6
# 3   260.9  100.5    78.3  200.6               8.6            864.5
# 4   540.0    0.0     0.0  173.0               0.0           1125.0
#
#    fineaggregate  age  csMPa
# 0          887.1   28  60.29
# 1          779.3  100  39.61
# 2          900.9   28  26.20
# 3          761.5   28  32.40
# 4          613.0    7  52.61
#
# Shape:
#  (824, 9)
#
# Description:
#             cement        slag      flyash       water  superplasticizer  \
# count  824.000000  824.000000  824.000000  824.000000        824.000000
# mean   282.254490   75.531068   51.794296  181.582767          6.151092
# std    104.978663   87.080259   63.877783   21.026110          5.937346
# ...

# %%
# Graphical exploration

print('Correlation Heatmap: \n')
corr_matrix = df_train.corr()
fig, ax = plt.subplots(figsize=(9,9))
sns.heatmap(corr_matrix,cmap='coolwarm',annot=True,ax=ax,square=True)
plt.show()

l = df_train.columns.values
number_of_columns=len(df_train.columns)
number_of_rows = round(len(l)-1/number_of_columns)

print('\nBoxplots: \n')
plt.figure(figsize=(1.2*number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(y=df_train[l[i]],color='green',orient='v')
    plt.tight_layout()
plt.show()
    
print('\nKernel Density Estimates: \n')
plt.figure(figsize=(1.5*number_of_columns,0.8*number_of_rows))
for i in range(len(l)):
    plt.subplot(2,5,i+1)
    sns.distplot(df_train[l[i]],kde=True)
    plt.tight_layout()
plt.show()
    
print('\nScatterplots: \n')
sns.pairplot(df_train)
plt.show()
# Out:
# Correlation Heatmap:
# Boxplots:
# Kernel Density Estimates:
# Scatterplots:

# %%
# Perform any changes based on EDA to both train and test datasets

# %%
# Write cleaned data to csv files
df_train.to_csv('cleaned_train_concrete.csv',index=False)
df_test.to_csv('cleaned_test_concrete.csv',index=False)
