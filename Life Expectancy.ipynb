# %%
# Imports
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
# Import data
train_data = pd.read_csv('life_expectancy_train.csv')
test_data = pd.read_csv('life_expectancy_test.csv')
train_data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
# Check info for preprocessing
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1999 non-null   object
#  1   Year                             1999 non-null   int64
#  2   Status                           1999 non-null   object
#  3   Life expectancy                  1992 non-null   float64
#  4   Adult Mortality                  1992 non-null   float64
#  5   infant deaths                    1999 non-null   int64
#  6   Alcohol                          1876 non-null   float64
#  7   percentage expenditure           1999 non-null   float64
#  8   Hepatitis B                      1619 non-null   float64
#  9   Measles                          1999 non-null   int64
#  10   BMI                             1998 non-null   float64
#  11  under-five deaths                1999 non-null   int64
#  12  Polio                            1993 non-null   float64
#  13  Total expenditure                1858 non-null   float64
#  14  Diphtheria                       1993 non-null   float64
#  15   HIV/AIDS                        1999 non-null   float64
#  16  GDP                              1775 non-null   float64
#  17  Population                       1621 non-null   float64
#  18   thinness  1-19 years            1998 non-null   float64
#  19   thinness 5-9 years              1998 non-null   float64
#  20  Income composition of resources  1930 non-null   float64
#  21  Schooling                        1932 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 343.7+ KB

# %%
# Preprocessing

# Remove leading and trailing spaces in column names
train_data.rename(columns=lambda x: x.strip(),inplace=True)
test_data.rename(columns=lambda x: x.strip(),inplace=True)

# Deal with NaN values
# print(train_data.isnull().sum())

# Drop year column
train_data.drop(['Year'],axis=1,inplace=True)
test_data.drop(['Year'],axis=1,inplace=True)

# Remove rows with null values in Life Expectancy
train_data = train_data[~train_data['Life expectancy'].isnull()]
test_data = test_data[~test_data['Life expectancy'].isnull()]

# Forward fill or backward fill null values in other columns
cols = train_data.columns
train_data[cols] = train_data[cols].fillna(train_data.groupby(['Country'])[cols].ffill().bfill())
cols = test_data.columns
test_data[cols] = test_data[cols].fillna(test_data.groupby(['Country'])[cols].ffill().bfill())

# Make object columns categorical
for col in ['Country','Status']:
    train_data[col] = train_data[col].astype('category')
    test_data[col] = test_data[col].astype('category')
    
# Make status numeric
status_num = {'Developing' : 0, 'Developed' : 1}
train_data['Developed'] = train_data['Status'].map(status_num)
train_data.drop(['Status'],axis=1,inplace=True)
test_data['Developed'] = test_data['Status'].map(status_num)
test_data.drop(['Status'],axis=1,inplace=True)


train_data.to_csv('life_expectancy_train_cleaned.csv',index=False)
test_data.to_csv('life_expectancy_test_cleaned.csv',index=False)

train_data.head(10)
# Out:
#        Country  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan             65.0            263.0             62     0.01
# 1  Afghanistan             59.9            271.0             64     0.01
# 2  Afghanistan             59.9            268.0             66     0.01
# 3  Afghanistan             59.5            272.0             69     0.01
# 4  Afghanistan             59.2            275.0             71     0.01
# 5  Afghanistan             58.8            279.0             74     0.01
# 6  Afghanistan             58.6            281.0             77     0.01
# 7  Afghanistan             58.1            287.0             80     0.03
# 8  Afghanistan             57.5            295.0             82     0.02
# 9  Afghanistan             57.3            295.0             84     0.03
#
#    percentage expenditure  Hepatitis B  Measles   BMI  under-five deaths  ...  \
# 0               71.279624         65.0     1154  19.1                 83  ...
# 1               73.523582         62.0      492  18.6                 86  ...
# 2               73.219243         64.0      430  18.1                 89  ...
# 3               78.184215         67.0     2787  17.6                 93  ...
# 4                7.097109         68.0     3013  17.2                 97  ...
# 5               79.679367         66.0     1989  16.7                102  ...
# 6               56.762217         63.0     2861  16.2                106  ...
# 7               25.873925         64.0     1599  15.7                110  ...
# 8               10.910156         63.0     1141  15.2                113  ...
# 9               17.171518         64.0     1990  14.7                116  ...
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0               8.16        65.0       0.1  584.259210  33736494.0
# 1               8.18        62.0       0.1  612.696514    327582.0
# 2               8.13        64.0       0.1  631.744976  31731688.0
# 3               8.52        67.0       0.1  669.959000   3696958.0
# 4               7.87        68.0       0.1   63.537231   2978599.0
# 5               9.20        66.0       0.1  553.328940   2883167.0
# 6               9.42        63.0       0.1  445.893298    284331.0
# 7               8.33        64.0       0.1  373.361116   2729431.0
# 8               6.73        63.0       0.1  369.835796  26616792.0
# 9               7.43        58.0       0.1  272.563770   2589345.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
# 5                  18.4                18.4                            0.448
# 6                  18.6                18.7                            0.434
# 7                  18.8                18.9                            0.433
# 8                  19.0                19.1                            0.415
# 9                  19.2                19.3                            0.405
#
#    Schooling  Developed
# 0       10.1          0
# 1       10.0          0
# 2        9.9          0
# 3        9.8          0
# 4        9.5          0
# 5        9.2          0
# 6        8.9          0
# 7        8.7          0
# 8        8.4          0
# 9        8.1          0
#
# [10 rows x 21 columns]

# %%
corr = train_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0a845_row0_col0,#T_0a845_row1_col1,#T_0a845_row2_col2,#T_0a845_row2_col8,#T_0a845_row3_col3,#T_0a845_row4_col4,#T_0a845_row5_col5,#T_0a845_row6_col6,#T_0a845_row7_col7,#T_0a845_row8_col2,#T_0a845_row8_col8,#T_0a845_row9_col9,#T_0a845_row10_col10,#T_0a845_row11_col11,#T_0a845_row12_col12,#T_0a845_row13_col13,#T_0a845_row14_col14,#T_0a845_row15_col15,#T_0a845_row16_col16,#T_0a845_row17_col17,#T_0a845_row18_col18{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0a845_row0_col1,#T_0a845_row0_col12,#T_0a845_row1_col0,#T_0a845_row1_col9,#T_0a845_row1_col11,#T_0a845_row5_col2,#T_0a845_row5_col8,#T_0a845_row5_col14,#T_0a845_row7_col2,#T_0a845_row7_col6,#T_0a845_row7_col8,#T_0a845_row7_col15,#T_0a845_row7_col16,#T_0a845_row8_col5,#T_0a845_row15_col3,#T_0a845_row15_col4,#T_0a845_row15_col7,#T_0a845_row15_col10,#T_0a845_row15_col13,#T_0a845_row15_col17,#T_0a845_row15_col18,#T_0a845_row16_col4,#T_0a845_row16_col7,#T_0a845_row16_col10,#T_0a845_row16_col13{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_0a845_row0_col2,#T_0a845_row0_col15,#T_0a845_row11_col8,#T_0a845_row15_col5,#T_0a845_row18_col14{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_0a845_row0_col3,#T_0a845_row5_col0,#T_0a845_row6_col8,#T_0a845_row15_col8{
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }#T_0a845_row0_col4,#T_0a845_row10_col7{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_0a845_row0_col5{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_0a845_row0_col6,#T_0a845_row1_col18{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_0a845_row0_col7{
#             background-color:  #f59c7d;
#             color:  #000000;
#         }#T_0a845_row0_col8,#T_0a845_row15_col9,#T_0a845_row16_col9{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_0a845_row0_col9,#T_0a845_row4_col3,#T_0a845_row15_col1,#T_0a845_row16_col1{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_0a845_row0_col10,#T_0a845_row8_col1{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_0a845_row0_col11{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_0a845_row0_col13,#T_0a845_row2_col6,#T_0a845_row8_col14,#T_0a845_row9_col17,#T_0a845_row10_col0{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_0a845_row0_col14,#T_0a845_row1_col5,#T_0a845_row1_col14,#T_0a845_row4_col14,#T_0a845_row12_col0,#T_0a845_row12_col9,#T_0a845_row17_col15,#T_0a845_row18_col16{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_0a845_row0_col16,#T_0a845_row3_col14,#T_0a845_row9_col6{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_0a845_row0_col17,#T_0a845_row0_col18{
#             background-color:  #ef886b;
#             color:  #000000;
#         }#T_0a845_row1_col2{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_0a845_row1_col3,#T_0a845_row2_col4,#T_0a845_row8_col4,#T_0a845_row8_col13{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_0a845_row1_col4,#T_0a845_row1_col13,#T_0a845_row15_col11{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_0a845_row1_col6,#T_0a845_row6_col4,#T_0a845_row10_col15,#T_0a845_row10_col16{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_0a845_row1_col7,#T_0a845_row1_col10{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_0a845_row1_col8,#T_0a845_row6_col3,#T_0a845_row13_col12{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_0a845_row1_col12{
#             background-color:  #f5a081;
#             color:  #000000;
#         }#T_0a845_row1_col15,#T_0a845_row1_col16,#T_0a845_row17_col11{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_0a845_row1_col17,#T_0a845_row2_col5,#T_0a845_row7_col14,#T_0a845_row10_col14{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_0a845_row2_col0,#T_0a845_row4_col12,#T_0a845_row5_col13{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_0a845_row2_col1{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_0a845_row2_col3{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_0a845_row2_col7,#T_0a845_row2_col18,#T_0a845_row11_col16,#T_0a845_row14_col4,#T_0a845_row14_col11{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_0a845_row2_col9{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_0a845_row2_col10,#T_0a845_row3_col2{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_0a845_row2_col11,#T_0a845_row3_col16,#T_0a845_row6_col5,#T_0a845_row10_col8{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_0a845_row2_col12,#T_0a845_row10_col4,#T_0a845_row13_col9,#T_0a845_row13_col11,#T_0a845_row17_col10{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_0a845_row2_col13{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_0a845_row2_col14{
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }#T_0a845_row2_col15,#T_0a845_row8_col15,#T_0a845_row11_col5{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_0a845_row2_col16,#T_0a845_row8_col16,#T_0a845_row9_col0,#T_0a845_row17_col7{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_0a845_row2_col17,#T_0a845_row5_col16{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_0a845_row3_col0{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_0a845_row3_col1{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_0a845_row3_col4,#T_0a845_row14_col15{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_0a845_row3_col5,#T_0a845_row8_col0,#T_0a845_row14_col3,#T_0a845_row14_col18{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_0a845_row3_col6,#T_0a845_row3_col8,#T_0a845_row12_col17{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_0a845_row3_col7,#T_0a845_row5_col9,#T_0a845_row15_col2{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_0a845_row3_col9{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_0a845_row3_col10{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_0a845_row3_col11{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_0a845_row3_col12{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_0a845_row3_col13{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_0a845_row3_col15,#T_0a845_row10_col2,#T_0a845_row12_col5,#T_0a845_row17_col16{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_0a845_row3_col17{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_0a845_row3_col18,#T_0a845_row13_col0,#T_0a845_row18_col3{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_0a845_row4_col0{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }#T_0a845_row4_col1{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_0a845_row4_col2,#T_0a845_row12_col4,#T_0a845_row15_col0{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_0a845_row4_col5,#T_0a845_row5_col15,#T_0a845_row8_col3{
#             background-col

# %%
X = train_data.drop(labels=['Life expectancy'], axis=1)
y = train_data['Life expectancy']
X_test = test_data.drop(labels=['Life expectancy'], axis=1)
y_test = test_data['Life expectancy']

encoder = LabelEncoder()
X['Country_cat'] = encoder.fit_transform(X['Country'])
X_test['Country_cat'] = encoder.fit_transform(X_test['Country'])
X.drop(['Country'],axis=1,inplace=True)
X_test.drop(['Country'],axis=1,inplace=True)

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
X_test = scaler.fit_transform(X)

X, y = shuffle(X, y, random_state=42)
X_test, y_test = shuffle(X_test, y_test, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# Random Forest Regression

n_estimators = [10,50,100,200,300,500]
max_depths = [1,2,3,4,5,6,7]
mses = {}

for n_estimator in n_estimators:
    for max_depth in max_depths:
        regressor = RandomForestRegressor(n_estimators=n_estimator, max_depth=max_depth)
        regressor.fit(X_train, y_train)
        y_out = regressor.predict(X_val)
        mse = mean_squared_error(y_val,y_out)
        mses[f'estimators {n_estimator}, max_depths {max_depth}'] = mse

# %%
min_value = np.min(list(mses.values()))
best_hp = list(mses.keys())[list(mses.values()).index(min_value)]
print("Best HPs", best_hp)
n_estimators = best_hp.split(' ')[1].replace(',','')
max_depth = best_hp.split(' ')[3]

# %%
regressor = RandomForestRegressor(n_estimators=int(n_estimators), max_depth=int(max_depth))
regressor.fit(X_train, y_train)
y_out = regressor.predict(X_val)
print(f'Validation error: {np.sqrt(mean_squared_error(y_val,y_out))}')
y_out = regressor.predict(X_test)
print(f'Test error: {np.sqrt(mean_squared_error(y_test,y_out))}')

# %%
grid = GridSearchCV(estimator=RandomForestRegressor(), param_grid={'n_estimators': [10,50,99,200,300,500], 'max_depth':[1,2,3,4,5,6,7]}, cv=5)
grid.fit(X_train, y_train.values.ravel())

grid.best_estimator_

# %%
def evaluate(model, test_features, test_labels):
    y_out = model.predict(test_features)
    mse = mean_squared_error(test_labels,y_out)
    rmse = np.sqrt(mse)
    
    print('Model Performance')
    print(f'Root Mean Squared Error: {rmse}')

evaluate(grid.best_estimator_, X_val, y_val)
evaluate(grid.best_estimator_, X_test, y_test)
